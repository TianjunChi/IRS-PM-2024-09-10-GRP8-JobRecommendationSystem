# %%
import pandas as pd

usecols=['Respondent',        #id
  'FormalEducation',    #degree
  'UndergradMajor',     #major
  'LanguageWorkedWith', 'DatabaseWorkedWith', 'PlatformWorkedWith', 'IDE', 'OperatingSystem', #skills
  'YearsCoding',        #projectExperience
  'Hobby',              #hobby
  'DevType',            #desiredJob
  ]

df = pd.read_csv('user_clean.csv', usecols=usecols)
df = df.rename(columns={
  'Respondent': 'id',
  'FormalEducation': 'degree',
  'UndergradMajor': 'major',
  'LanguageWorkedWith': 'skills_1',
  'DatabaseWorkedWith': 'skills_2',
  'PlatformWorkedWith': 'skills_3',
  'IDE': 'skills_4',
  'OperatingSystem': 'skills_5',
  'YearsCoding': 'projectExperience',
  'Hobby': 'hobby',
  'DevType': 'desiredJob',
})

df.head()
# Out:
#      id hobby                                       degree  \
# 0   569   Yes    Other doctoral degree (Ph.D, Ed.D., etc.)
# 1  1142   Yes     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  1886   Yes     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3  2208    No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4  3285   Yes     Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                major  \
# 0  Another engineering discipline (ex. civil, ele...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Information systems, information technology, o...
# 4  Computer science, computer engineering, or sof...
#
#                                           desiredJob projectExperience  \
# 0  Data scientist or machine learning specialist;...       12-14 years
# 1  Back-end developer;Front-end developer;Full-st...         6-8 years
# 2  Back-end developer;Desktop or enterprise appli...         3-5 years
# 3  Back-end developer;Front-end developer;Full-st...        9-11 years
# 4  Back-end developer;Front-end developer;Full-st...        9-11 years
#
#                                        skills_1  \
# 0                              C++;Julia;Python
# 1   C++;Java;JavaScript;SQL;HTML;CSS;Bash/Shell
# 2                        C#;JavaScript;HTML;CSS
# 3                                           NaN
# 4  C#;JavaScript;Python;SQL;TypeScript;HTML;CSS
#
#                                             skills_2  \
# 0                                                NaN
# 1  MongoDB;Oracle;Google Cloud Storage;Elasticsearch
# 2                            SQL Server;MySQL;SQLite
# 3                                                NaN
# 4                                         SQL Server
#
#                                             skills_3  \
# 0                                              Linux
# 1                                                NaN
# 2                          Windows Desktop or Server
# 3                                                NaN
# 4  Android;AWS;Google Cloud Platform/App Engine;W...
#
#                                             skills_4     skills_5
# 0       Atom;IntelliJ;Notepad++;PyCharm;Sublime Text  Linux-based
# 1                     Eclipse;IntelliJ;Notepad++;Vim  Linux-based
# 2                                      Visual Studio      Windows
# 3                                                NaN          NaN
# 4  Android Studio;Notepad++;Visual Studio;Visual ...      Windows

# %%
df_onehot = pd.get_dummies(df['degree'])
df['degree'] = df_onehot.apply(lambda x: x.values.tolist(), axis=1)
df_onehot = pd.get_dummies(df['major'])
df['major'] = df_onehot.apply(lambda x: x.values.tolist(), axis=1)
df_onehot = pd.get_dummies(df['projectExperience'])
df['projectExperience'] = df_onehot.apply(lambda x: x.values.tolist(), axis=1)

# %%
df['skills_1'] = df['skills_1'].str.split(';')
df['skills_2'] = df['skills_2'].str.split(';')
df['skills_3'] = df['skills_3'].str.split(';')
df['skills_4'] = df['skills_4'].str.split(';')
df['skills_5'] = df['skills_5'].str.split(';')

df['skills'] = df[['skills_1', 'skills_2', 'skills_3', 'skills_4', 'skills_5']].apply(lambda x: sum([i for i in x if isinstance(i, list)], []), axis=1)
df.drop(columns=['skills_1', 'skills_2', 'skills_3', 'skills_4', 'skills_5'], inplace=True)
# df = pd.concat([df_onehot, df['skills']], axis=1)

# %%
df['hobby'] = df['hobby'].apply(lambda x: 'True' if x == 'Yes' else 'False')
df['desiredJob'] = df['desiredJob'].str.split(';')
df['desiredJob'] = df[['desiredJob']].apply(lambda x: sum([i for i in x if isinstance(i, list)], []), axis=1)
# df['desiredJob'] = df['desiredJob'].apply(lambda x: [] if pd.isnull(str(x)) else x)
df
# Out:
#         id  hobby                                            degree  \
# 0      569   True  [False, False, False, True, False, False, False]
# 1     1142   True  [False, True, False, False, False, False, False]
# 2     1886   True  [False, True, False, False, False, False, False]
# 3     2208  False  [False, False, True, False, False, False, False]
# 4     3285   True  [False, True, False, False, False, False, False]
# ..     ...    ...                                               ...
# 275  41042   True  [False, True, False, False, False, False, False]
# 276  79707   True  [False, True, False, False, False, False, False]
# 277  18712   True  [False, False, True, False, False, False, False]
# 278  79245   True  [False, False, True, False, False, False, False]
# 279  90067   True  [False, True, False, False, False, False, False]
#
#                                                  major  \
# 0    [False, False, False, False, False, True, Fals...
# 1    [False, False, False, False, False, False, Tru...
# 2    [False, False, False, False, False, False, Tru...
# 3    [False, False, False, False, False, False, Fal...
# 4    [False, False, False, False, False, False, Tru...
# ..                                                 ...
# 275  [False, False, False, False, False, False, Tru...
# 276  [False, False, False, True, False, False, Fals...
# 277  [False, False, False, False, False, False, Tru...
# 278  [False, False, False, False, False, False, Fal...
# 279  [False, False, False, False, False, False, Tru...
#
#                                             desiredJob  \
# 0    [Data scientist or machine learning specialist...
# 1    [Back-end developer, Front-end developer, Full...
# 2    [Back-end developer, Desktop or enterprise app...
# 3    [Back-end developer, Front-end developer, Full...
# 4    [Back-end developer, Front-end developer, Full...
# ..                                                 ...
# 275                  [Educator or academic researcher]
# 276     [Desktop or enterprise applications developer]
# 277         [Back-end developer, Full-stack developer]
# 278  [Back-end developer, C-suite executive (CEO, C...
# 279           [Full-stack developer, Mobile developer]
#
#                                      projectExperience  \
# 0    [False, True, False, False, False, False, Fals...
# 1    [False, False, False, False, False, False, Fal...
# 2    [False, False, False, False, False, False, Fal...
# 3    [False, False, False, False, False, False, Fal...
# 4    [False, False, False, False, False, False, Fal...
# ..                                                 ...
# 275  [False, False, True, False, False, False, Fals...
# 276  [False, False, False, False, False, False, Fal...
# 277  [False, False, False, False, False, False, Fal...
# 278  [False, False, False, False, False, False, Fal...
# 279  [False, False, False, False, False, False, Fal...
#
#                                                 skills
# 0    [C++, Julia, Python, Linux, Atom, IntelliJ, No...
# 1    [C++, Java, JavaScript, SQL, HTML, CSS, Bash/S...
# 2    [C#, JavaScript, HTML, CSS, SQL Server, MySQL,...
# 3                                                   []
# 4    [C#, JavaScript, Python, SQL, TypeScript, HTML...
# ..                                                 ...
# 275  [C, C++, C#, Java, JavaScript, HTML, SQL Serve...
# 276  [Groovy, Java, Python, Bash/Shell, Eclipse, Em...
# 277  [Java, VB.NET, MongoDB, SQL Server, Oracle, Ec...
# 278                                                 []
# 279                                                 []
#
# [280 rows x 7 columns]

# %%
df.to_csv('user_precessed.csv', index=False)

# %%
import pandas as pd
import numpy as np
from scipy.special import softmax

# Function to calculate Jaccard similarity for binary vectors (one-hot encoded)
def jaccard_similarity_binary(vector1, vector2):
    set1, set2 = set(np.where(vector1 == 1)[0]), set(np.where(vector2 == 1)[0])
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    if union == 0:
        return 0
    return intersection / union

# Function to calculate Jaccard similarity for lists of strings
def jaccard_similarity(list1, list2):
    set1, set2 = set(list1), set(list2)
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    if union == 0:
        return 0
    return intersection / union

# Load the dataset
file_path = 'user_precessed.csv'
df = pd.read_csv(file_path)

# Convert string representations of lists back to actual lists
list_columns = ['degree', 'major', 'desiredJob', 'projectExperience', 'skills']
for col in list_columns:
    df[col] = df[col].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Separate the new user (last row) from the rest of the data
new_user = df.iloc[0]
# new_user.id = 0
# new_user.hobby = 
# new_user.degree = 
# new_user.major = 
# new_user.desiredJob = 
# new_user.projectExperience = 
# new_user.skills = 
other_users = df

# Similarity calculation for each feature

# 1. Similarity for 'hobby' (boolean comparison)
hobby_similarity = other_users['hobby'].apply(lambda x: 10 if x == new_user['hobby'] else 0)

# 2. Similarity for one-hot encoded features (degree, major, projectExperience)
onehot_similarity = []
for idx, other_user in other_users.iterrows():
    degree_sim = jaccard_similarity_binary(np.array(new_user['degree']), np.array(other_user['degree']))
    major_sim = jaccard_similarity_binary(np.array(new_user['major']), np.array(other_user['major']))
    project_sim = jaccard_similarity_binary(np.array(new_user['projectExperience']), np.array(other_user['projectExperience']))
    onehot_similarity.append((degree_sim + major_sim + project_sim) / 0.3)

# 3. Similarity for lists of strings (desiredJob, skills)
list_similarity = []
for idx, other_user in other_users.iterrows():
    desiredJob_sim = jaccard_similarity(new_user['desiredJob'], other_user['desiredJob'])
    skills_sim = jaccard_similarity(new_user['skills'], other_user['skills'])
    list_similarity.append((desiredJob_sim + skills_sim) / 0.2)

# Combine similarities with equal weights
total_similarities = hobby_similarity / 6 + np.array(onehot_similarity) / 2 + np.array(list_similarity) / 3

# Create a DataFrame to display similarities
similarities_df = pd.DataFrame({
    'UserIndex': other_users.id,
    'HobbySimilarity': hobby_similarity,
    'OneHotSimilarity': onehot_similarity,
    'ListSimilarity': list_similarity,
    'TotalSimilarity': total_similarities
})

# Sort by total similarity
similarities_df = similarities_df.sort_values(by='UserIndex', ascending=True)

# Display the top results
# Apply softmax to the 'TotalSimilarity' column
similarities_df['TotalSimilarity_softmax'] = softmax(similarities_df['TotalSimilarity'])

# Display the top results
similarities_df
# Out:
#      UserIndex  HobbySimilarity  OneHotSimilarity  ListSimilarity  \
# 0          569               10              10.0       10.000000
# 1         1142               10               0.0        0.909091
# 268       1525               10               0.0        1.250000
# 2         1886               10               0.0        0.000000
# 3         2208                0               0.0        0.000000
# ..         ...              ...               ...             ...
# 254     100195                0               0.0        0.217391
# 255     100266               10               0.0        0.483871
# 266     100400               10               0.0        0.370370
# 256     100548                0               0.0        0.192308
# 267     101248                0               0.0        0.000000
#
#      TotalSimilarity  TotalSimilarity_softmax
# 0          10.000000                 0.853012
# 1           1.969697                 0.000278
# 268         2.083333                 0.000311
# 2           1.666667                 0.000205
# 3           0.000000                 0.000039
# ..               ...                      ...
# 254         0.072464                 0.000042
# 255         1.827957                 0.000241
# 266         1.790123                 0.000232
# 256         0.064103                 0.000041
# 267         0.000000                 0.000039
#
# [280 rows x 6 columns]

# %%
import numpy as np
data = np.load(r'E:\OneDrive - National University of Singapore\code\NUS-ISS\Project1\IRS-PM-2024-09-10-GRP8-JobRecommendationSystem\Recommendation_System\KGAT\trained_model\KGAT\ours\pretrain0\cf_scores.npy')
data[data == -np.inf] = 0
print(data)
# Out:
# [[2.5094125  0.5457798  0.86320585 ... 0.64694655 0.5428725  2.9614866 ]
#  [1.7571821  0.4797321  0.7343855  ... 0.5962142  0.47354534 2.7825584 ]
#  [1.8190633  0.4703961  0.7303033  ... 0.5873413  0.46456838 2.8192024 ]
#  ...
#  [1.7981231  0.48968816 0.7388602  ... 0.60602975 0.48801172 2.800873  ]
#  [2.4156559  0.46187967 0.80723965 ... 0.58620405 0.46363518 2.9865808 ]
#  [1.8656905  0.48238537 0.73182285 ... 0.5938782  0.4776994  2.8391533 ]]

# %%
# Ensure that similarities_df['TotalSimilarity_softmax'] is a numpy array
similarity_scores = np.array(similarities_df['TotalSimilarity_softmax'].tolist())

# Perform the dot product
result = np.dot(similarity_scores, data)

# Convert the result to a list
result_list = result.tolist() + [0,0,0,0]
result_list
# Out:
# [2.4394859712445878,
#  0.540026210825465,
#  0.850311454918213,
#  2.8629493494824656,
#  0.696847857301082,
#  0.5070443626371934,
#  0.4591972123685144,
#  0.5168144821446655,
#  0.4700452711370951,
#  0.4834864504974843,
#  0.560939699897996,
#  2.468282459787559,
#  2.146153668623719,
#  0.5381573432446949,
#  2.907323623693075,
#  0.5539899638695976,
#  0.528138531462918,
#  0.6157063281224211,
#  2.917354132505008,
#  0.5197793224308039,
#  2.756413433290587,
#  0.5931657920479537,
#  0.44224197553474215,
#  2.4528958026710828,
#  2.9190307996598137,
#  2.9081590919497065,
#  0.6662433000721253,
#  2.829942813972736,
#  0.5889083062288446,
#  2.834621263913426,
#  2.881093634862611,
#  0.5200946353442465,
#  0.497344858532477,
#  0.4894928472925787,
#  0.5030413609387138,
#  0.5290285605459364,
#  0.5879843131379129,
#  2.829773382258573,
#  0.5130566916498868,
#  0.6280013678174144,
#  2.923708625867347,
#  0.4922174311016919,
#  0.4695365242316987,
#  0.5237754526697757,
#  0.4521455547711364,
#  0.5054340882290275,
#  2.460670311531097,
#  0.5066232995711833,
#  0.6549031610773308,
#  0.4740976997108277,
#  0.5572849532481298,
#  0.5408450116524344,
#  0.5044894728776302,
#  0.5561968964521808,
#  0.5730713974857449,
#  0.4666177560396431,
#  0.4724017180721068,
#  0.5751460174560938,
#  0.6113708575273321,
#  0.5344638925624458,
#  2.9587077711727474,
#  0.674032399763475,
#  2.4203051856998195,
#  0.6025058564795925,
#  0.46541257657235424,
#  0.5138950586076723,
#  0.47481885352643377,
#  0.5361658952148636,
#  0.5219238909483905,
#  0.4735334155189379,
#  2.9482401828793265,
#  0.45330299194018403,
#  0.48514471816281696,
#  2.798773351716184,
#  0.4961442996194942,
#  2.589068471318498,
#  2.824696758509606,
#  0.518362821853007,
#  2.5814116947162824,
#  0.5546452645832938,
#  0.5577695768644377,
#  2.909085193815284,
#  2.948490660516945,
#  0.6054401181109825,
#  0.5204198263924376,
#  2.8618844736973275,
#  0.49946134454455626,
#  0.5056194475004944,
#  2.6992763085782485,
#  0.5044631153935005,
#  0.470708794320978,
#  0.5970721875207194,
#  0.5425218059474174,
#  0.5307278134973612,
#  0.49353644997811047,
#  0.4681406786698128,
#  0.5337552255217733,
#  0.4791645533060041,
#  0.5041670548629671,
#  0.545554391573462,
#  0.5367871904538627,
#  0.5944044461887427,
#  0.5098145788898103,
#  2.855095432055332,
#  0.6665421557921318,
#  2.537259110307564,
#  0.56937003287706,
#  0.540351918378436,
#  0.4931672572725353,
#  0.5512541913140243,
#  0.5007128693124332,
#  2.6308811116802517,
#  0.5169734354612275,
#  0.4844671369526245,
#  0.5642544979081717,
#  2.6324265921344514,
#  2.902201247271632,
#  2.9229297213122813,
#  0.5428470727205117,
#  0.735808012193742,
#  2.809864541094738,
#  2.8807115810156527,
#  ...]

# %%
item_list_path = r'E:\OneDrive - National University of Singapore\code\NUS-ISS\Project1\IRS-PM-2024-09-10-GRP8-JobRecommendationSystem\Recommendation_System\KGAT\datasets\ours\item_list.txt'
with open(item_list_path, 'r') as f:
    item_list = f.readlines()
data = [line.split() for line in item_list]
df = pd.DataFrame(data)
df['result_list'] = result_list
df.drop(columns=[0, 1], inplace=True)
df.rename(columns={2: 'job_id'}, inplace=True)
final_result = df.sort_values(by='result_list', ascending=False)
final_result
# Out:
#                 job_id  result_list
# 4578   282207519167069     2.968246
# 5980  2274028337211999     2.966311
# 774    727574892043583     2.966018
# 5816  1724357497952342     2.965610
# 1331   757709400083644     2.965398
# ...                ...          ...
# 2338  1151137082912564     0.300732
# 7421  3017880610488563     0.000000
# 7422  2670092777939025     0.000000
# 7423   158667622654558     0.000000
# 7424  2227301158722256     0.000000
#
# [7425 rows x 2 columns]
